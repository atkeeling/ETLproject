# %%
import pandas as pd

# %% [markdown]
# ## Read CSVs

# %%
billboard = pd.read_csv("data/billboard.csv", index_col = 0)
itunes = pd.read_csv("data/itunes.csv", index_col = 0)
shazam = pd.read_csv("data/shazam.csv", index_col = 0)
spotify = pd.read_csv("data/spotify_csv_data.csv", index_col = 0)

# %% [markdown]
# ## Clean Billboard data

# %%
billboard = billboard.drop_duplicates(subset=["song_title","artist"])
billboard["song_title"] = [item[0] for item in billboard["song_title"].str.split("(")]
billboard["song_title"] = billboard["song_title"].str.lower()
billboard["song_title"] = billboard["song_title"].str.strip()
billboard["artist"] = billboard["artist"].str.lower()
billboard["artist"] = billboard["artist"].str.strip()
billboard.count()
# Out:
# song_title             100
# artist                 100
# billboard_rank         100
# billboard_last_week     85
# billboard_peak         100
# billboard_duration     100
# dtype: int64

# %%
billboard.head()
# Out:
#             song_title                         artist  billboard_rank  \
# 0  highest in the room                   travis scott               1
# 1          truth hurts                          lizzo               2
# 2             senorita  shawn mendes & camila cabello               3
# 3         10,000 hours     dan + shay & justin bieber               4
# 4    someone you loved                  lewis capaldi               5
#
#    billboard_last_week  billboard_peak  billboard_duration
# 0                  NaN               1                   1
# 1                  1.0               1                  23
# 2                  2.0               1                  16
# 3                  NaN               4                   1
# 4                  3.0               3                  22

# %% [markdown]
# ## Clean iTunes data

# %%
itunes.count()
# Out:
# itunes_rank    200
# song_title     200
# artist         200
# genre          200
# dtype: int64

# %%
itunes = itunes.drop_duplicates(subset=["song_title","artist"])
itunes["song_title"] = [item[0] for item in itunes["song_title"].str.split("(")]
itunes["song_title"] = itunes["song_title"].str.lower()
itunes["song_title"] = itunes["song_title"].str.strip()
itunes["artist"] = itunes["artist"].str.lower()
itunes["artist"] = itunes["artist"].str.strip()
itunes.count()
# Out:
# itunes_rank    195
# song_title     195
# artist         195
# genre          195
# dtype: int64

# %%
itunes.head()
# Out:
#    itunes_rank         song_title                      artist          genre
# 0          1.0           memories                    maroon 5            Pop
# 1          2.0       10,000 hours  dan + shay & justin bieber        Country
# 2          3.0            circles                 post malone  Hip Hop / Rap
# 3          4.0        truth hurts                       lizzo            Pop
# 4          5.0  someone you loved               lewis capaldi    Alternative

# %% [markdown]
# ## Clean Shazam data

# %%
shazam.count()
# Out:
# song_name      200
# artist         200
# shazam_rank    200
# dtype: int64

# %%
shazam = shazam.rename(columns={"song_name": "song_title"})
shazam["song_title"] = [item[0] for item in shazam["song_title"].str.split("(")]
shazam["song_title"] = shazam["song_title"].str.lower()
shazam["song_title"] = shazam["song_title"].str.strip()
shazam["artist"] = shazam["artist"].str.lower()
shazam["artist"] = shazam["artist"].str.strip()
shazam.count()
# Out:
# song_title     200
# artist         200
# shazam_rank    200
# dtype: int64

# %%
shazam.head()
# Out:
#           song_title                     artist  shazam_rank
# 0  someone you loved              lewis capaldi            1
# 1           memories                   maroon 5            2
# 2            circles                post malone            3
# 3            ballin’  mustard feat. roddy ricch            4
# 4        truth hurts                      lizzo            5

# %% [markdown]
# ## Clean Spotify data

# %%
spotify.count()
# Out:
# song_title         100
# artist             100
# spotify_streams    100
# dtype: int64

# %%
spotify = spotify.reset_index()
spotify["song_title"] = [item[0] for item in spotify["song_title"].str.split("(")]
spotify["song_title"] = spotify["song_title"].str.lower()
spotify["song_title"] = spotify["song_title"].str.strip()
spotify["artist"] = spotify["artist"].str.lower()
spotify["artist"] = spotify["artist"].str.strip()
spotify.count()
# Out:
# spotify_rank       100
# song_title         100
# artist             100
# spotify_streams    100
# dtype: int64

# %%
spotify.head()
# Out:
#    spotify_rank           song_title        artist  spotify_streams
# 0             1  highest in the room  travis scott         20518547
# 1             2         10,000 hours    dan + shay         11129577
# 2             3              circles   post malone         10046611
# 3             4               bandit    juice wrld          9652455
# 4             5                223's     ynw melly          7409895

# %% [markdown]
# ## Merge DataFrames

# %%
bill_itunes = pd.merge(billboard, itunes, how="outer", on=["song_title","artist"])
bill_itunes
# Out:
#               song_title                         artist  billboard_rank  \
# 0    highest in the room                   travis scott             1.0
# 1            truth hurts                          lizzo             2.0
# 2               senorita  shawn mendes & camila cabello             3.0
# 3           10,000 hours     dan + shay & justin bieber             4.0
# 4      someone you loved                  lewis capaldi             5.0
# ..                   ...                            ...             ...
# 240               panini             lil nas x & dababy             NaN
# 241         ghostbusters                 ray parker jr.             NaN
# 242        rearview town                   jason aldean             NaN
# 243              we were                    keith urban             NaN
# 244                   us                      james bay             NaN
#
#      billboard_last_week  billboard_peak  billboard_duration  itunes_rank  \
# 0                    NaN             1.0                 1.0         31.0
# 1                    1.0             1.0                23.0          4.0
# 2                    2.0             1.0                16.0          NaN
# 3                    NaN             4.0                 1.0          2.0
# 4                    3.0             3.0                22.0          5.0
# ..                   ...             ...                 ...          ...
# 240                  NaN             NaN                 NaN        196.0
# 241                  NaN             NaN                 NaN        197.0
# 242                  NaN             NaN                 NaN        198.0
# 243                  NaN             NaN                 NaN        199.0
# 244                  NaN             NaN                 NaN        200.0
#
#              genre
# 0    Hip Hop / Rap
# 1              Pop
# 2              NaN
# 3          Country
# 4      Alternative
# ..             ...
# 240  Hip Hop / Rap
# 241     Soundtrack
# 242        Country
# 243        Country
# 244    Alternative
#
# [245 rows x 8 columns]

# %%
bill_it_spot = pd.merge(bill_itunes, spotify, how="outer", on=["song_title","artist"])
bill_it_spot
# Out:
#               song_title                         artist  billboard_rank  \
# 0    highest in the room                   travis scott             1.0
# 1            truth hurts                          lizzo             2.0
# 2               senorita  shawn mendes & camila cabello             3.0
# 3           10,000 hours     dan + shay & justin bieber             4.0
# 4      someone you loved                  lewis capaldi             5.0
# ..                   ...                            ...             ...
# 294               better                         khalid             NaN
# 295              7 rings                  ariana grande             NaN
# 296           goosebumps                   travis scott             NaN
# 297           pure water                        mustard             NaN
# 298              robbery                     juice wrld             NaN
#
#      billboard_last_week  billboard_peak  billboard_duration  itunes_rank  \
# 0                    NaN             1.0                 1.0         31.0
# 1                    1.0             1.0                23.0          4.0
# 2                    2.0             1.0                16.0          NaN
# 3                    NaN             4.0                 1.0          2.0
# 4                    3.0             3.0                22.0          5.0
# ..                   ...             ...                 ...          ...
# 294                  NaN             NaN                 NaN          NaN
# 295                  NaN             NaN                 NaN          NaN
# 296                  NaN             NaN                 NaN          NaN
# 297                  NaN             NaN                 NaN          NaN
# 298                  NaN             NaN                 NaN          NaN
#
#              genre  spotify_rank  spotify_streams
# 0    Hip Hop / Rap           1.0       20518547.0
# 1              Pop           6.0        7065663.0
# 2              NaN           NaN              NaN
# 3          Country           NaN              NaN
# 4      Alternative           9.0        6105495.0
# ..             ...           ...              ...
# 294            NaN          94.0        2188753.0
# 295            NaN          95.0        2172126.0
# 296            NaN          96.0        2165826.0
# 297            NaN          97.0        2146547.0
# 298            NaN          99.0        2142075.0
#
# [299 rows x 10 columns]

# %%
all_data = pd.merge(bill_it_spot, shazam, how="outer", on=["song_title","artist"])
all_data
# Out:
#               song_title                                   artist  \
# 0    highest in the room                             travis scott
# 1            truth hurts                                    lizzo
# 2               senorita            shawn mendes & camila cabello
# 3           10,000 hours               dan + shay & justin bieber
# 4      someone you loved                            lewis capaldi
# ..                   ...                                      ...
# 400         what you did                   mahalia feat. ella mai
# 401          steady love                               india.arie
# 402        under the sun  dreamville, j. cole & lute feat. dababy
# 403  piece of your heart                    meduza feat. goodboys
# 404               maayaa       juls feat. tiggs da author & santi
#
#      billboard_rank  billboard_last_week  billboard_peak  billboard_duration  \
# 0               1.0                  NaN             1.0                 1.0
# 1               2.0                  1.0             1.0                23.0
# 2               3.0                  2.0             1.0                16.0
# 3               4.0                  NaN             4.0                 1.0
# 4               5.0                  3.0             3.0                22.0
# ..              ...                  ...             ...                 ...
# 400             NaN                  NaN             NaN                 NaN
# 401             NaN                  NaN             NaN                 NaN
# 402             NaN                  NaN             NaN                 NaN
# 403             NaN                  NaN             NaN                 NaN
# 404             NaN                  NaN             NaN                 NaN
#
#      itunes_rank          genre  spotify_rank  spotify_streams  shazam_rank
# 0           31.0  Hip Hop / Rap           1.0       20518547.0         23.0
# 1            4.0            Pop           6.0        7065663.0          5.0
# 2            NaN            NaN           NaN              NaN          NaN
# 3            2.0        Country           NaN              NaN         21.0
# 4            5.0    Alternative           9.0        6105495.0          1.0
# ..           ...            ...           ...              ...          ...
# 400          NaN            NaN           NaN              NaN        191.0
# 401          NaN            NaN           NaN              NaN        194.0
# 402          NaN            NaN           NaN              NaN        196.0
# 403          NaN            NaN           NaN              NaN        197.0
# 404          NaN            NaN           NaN              NaN        200.0
#
# [405 rows x 11 columns]

# %% [markdown]
# ## Combine song titles with varying artist names

# %%
all_data2 = all_data.groupby("song_title")
all_data2.max().reset_index()
# Out:
#                 song_title                       artist  billboard_rank  \
# 0                1, 2 many   luke combs & brooks & dunn             NaN
# 1             10,000 hours   dan + shay & justin bieber             4.0
# 2                    11 pm                       maluma             NaN
# 3                       16               highly suspect             NaN
# 4                    223's    ynw melly feat. 9lokknine            37.0
# ..                     ...                          ...             ...
# 331                    yes  fat joe, cardi b & anuel aa             NaN
# 332     you are the reason    calum scott & leona lewis             NaN
# 333  you need to calm down                 taylor swift            28.0
# 334                you say                lauren daigle             NaN
# 335             youngblood          5 seconds of summer             NaN
#
#      billboard_last_week  billboard_peak  billboard_duration  itunes_rank  \
# 0                    NaN             NaN                 NaN        136.0
# 1                    NaN             4.0                 1.0          2.0
# 2                    NaN             NaN                 NaN          NaN
# 3                    NaN             NaN                 NaN        150.0
# 4                   34.0            34.0                 5.0        135.0
# ..                   ...             ...                 ...          ...
# 331                  NaN             NaN                 NaN        184.0
# 332                  NaN             NaN                 NaN        174.0
# 333                 27.0             2.0                17.0         23.0
# 334                  NaN             NaN                 NaN         21.0
# 335                  NaN             NaN                 NaN        194.0
#
#      spotify_rank  spotify_streams  shazam_rank
# 0             NaN              NaN          NaN
# 1             2.0       11129577.0         21.0
# 2             NaN              NaN        189.0
# 3             NaN              NaN        123.0
# 4             5.0        7409895.0         61.0
# ..            ...              ...          ...
# 331           NaN              NaN         46.0
# 332           NaN              NaN          NaN
# 333          65.0        2582875.0        128.0
# 334           NaN              NaN         54.0
# 335           NaN              NaN        164.0
#
# [336 rows x 10 columns]

# %%
all_data2.max().reset_index().to_csv(r'all_data.csv')
