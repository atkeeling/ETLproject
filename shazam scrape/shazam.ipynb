# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
executable_path = {'executable_path': '../chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://www.shazam.com/charts/top-200/united-states"
browser.visit(url)

# %%
t = []
a = []

# %%
t = []
a = []
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
titles = soup.find_all('div', class_='title')
artist = soup.find_all('div', class_='artist')
for x in titles:
    t.append(x.text)
for y in artist:
    a.append(y.text)

# %%
df= pd.DataFrame()
df["song_name"] = t
df["artist"]=a
df["shazam_rank"] = range(1,201)
df
# Out:
#                             song_name  \
# 0                  Someone You Loved
# 1                           Memories
# 2                            Circles
# 3                            Ballin’
# 4                        Truth Hurts
# 5                               Time
# 6                           On Chill
# 7                         Only Human
# 8         Sharing The Night Together
# 9                        No Guidance
# 10                              Heat
# 11                      Dance Monkey
# 12                        Trampoline
# 13                             Lover
# 14                  Beautiful People
# 15                 How Do You Sleep?
# 16                    Leave Em Alone
# 17                   One Thing Right
# 18                        Hot Shower
# 19                            Panini
# 20                      10,000 Hours
# 21                   Hot Girl Summer
# 22               Highest In The Room
# 23                          Goodbyes
# 24                          Señorita
# 25                      Good As Hell
# 26                     Baila Conmigo
# 27                              Baby
# 28                               Hot
# 29                            Ransom
# ..                                ...
# 170                    Old Town Road
# 171          Water On Water On Water
# 172                         Eastside
# 173                   Can We Pretend
# 174                           Adicto
# 175                    Qué Pretendes
# 176             Amor A Primera Vista
# 177          Scars To Your Beautiful
# 178               House Arrest Tingz
# 179                           Choosy
# 180   La Mejor Versión De Mi (Remix)
# 181                           Cringe
# 182                       High Hopes
# 183                             Ride
# 184                Tennessee Whiskey
# 185                   Make It Better
# 186                            Toast
# 187                         War Pigs
# 188                            11 Pm
# 189                   All Night Long
# 190                     What You Did
# 191                          Shallow
# 192                     Self Control
# 193                      Steady Love
# 194                          Happier
# 195                    Under The Sun
# 196              Piece Of Your Heart
# 197                       SICKO MODE
# 198                 Sweet But Psycho
# 199                           Maayaa
#
#                                                 artist  shazam_rank
# 0                                       Lewis Capaldi             1
# 1                                            Maroon 5             2
# 2                                         Post Malone             3
# 3                           Mustard Feat. Roddy Ricch             4
# 4                                               Lizzo             5
# 5                                                  NF             6
# 6                                  Wale Feat. Jeremih             7
# 7                                      Jonas Brothers             8
# 8                                            Dr. Hook             9
# 9                             Chris Brown Feat. Drake            10
# 10                            Chris Brown Feat. Gunna            11
# 11                                        Tones And I            12
# 12                                              SHAED            13
# 13                                       Taylor Swift            14
# 14                            Ed Sheeran Feat. Khalid            15
# 15                                          Sam Smith            16
# 16    Layton Greene, Lil Baby & City Girls Feat. Pn...           17
# 17                            Marshmello & Kane Brown            18
# 18         Chance The Rapper Feat. MadeinTYO & DaBaby            19
# 19                                          Lil Nas X            20
# 20                         Dan + Shay & Justin Bieber            21
# 21    Megan Thee Stallion Feat. Nicki Minaj & Ty Do...           22
# 22                                       Travis Scott            23
# 23                       Post Malone Feat. Young Thug            24
# 24                      Shawn Mendes & Camila Cabello            25
# 25                                              Lizzo            26
# 26           Dayvi & Victor Cárdenas Feat. Kelly Ruiz            27
# 27                 Quality Control, Lil Baby & DaBaby            28
# 28                             Young Thug Feat. Gunna            29
# 29                                          Lil Tecca            30
# ..                                                 ...          ...
# 170                                         Lil Nas X           171
# 171                           Young Dolph & Key Glock           172
# 172                     Benny Blanco, Halsey & Khalid           173
# 173                              P!nk Feat. Cash Cash           174
# 174                           Tainy, Anuel AA & Ozuna           175
# 175                              J Balvin & Bad Bunny           176
# 176   Los Ángeles Azules, Belinda & Lalo Ebratt Fea...          177
# 177                                      Alessia Cara           178
# 178                        YoungBoy Never Broke Again           179
# 179                   Fabolous Feat. Jeremih & Davido           180
# 180                      Natti Natasha & Romeo Santos           181
# 181                                       Matt Maeson           182
# 182                               Panic! At The Disco           183
# 183                           YK Osiris Feat. Kehlani           184
# 184                                   Chris Stapleton           185
# 185              Anderson .Paak Feat. Smokey Robinson           186
# 186                                            Koffee           187
# 187                                     Black Sabbath           188
# 188                                            Maluma           189
# 189                        YFN Lucci Feat. Trey Songz           190
# 190                            Mahalia Feat. Ella Mai           191
# 191                        Lady Gaga & Bradley Cooper           192
# 192                        YoungBoy Never Broke Again           193
# 193                                        India.Arie           194
# 194                             Marshmello & Bastille           195
# 195           Dreamville, J. Cole & Lute Feat. DaBaby           196
# 196                             Meduza Feat. Goodboys           197
# 197                                      Travis Scott           198
# 198                                           Ava Max           199
# 199                Juls Feat. Tiggs Da Author & Santi           200
#
# [200 rows x 3 columns]

# %%
type(df["artist"][0])
# Out:
# str

# %%
df.to_csv(os.path.join("..","data","shazam.csv"))
